# %%
#First Import The Libraries That Are Needed:-
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
#Now just take a look at the dataset first:-
df=pd.read_csv('kaggle_diabetes.csv')
df
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138             62             35        0  33.6
# 1               0       84             82             31      125  38.2
# 2               0      145              0              0        0  44.2
# 3               0      135             68             42      250  42.3
# 4               1      139             62             41      480  40.7
# ...           ...      ...            ...            ...      ...   ...
# 1995            2       75             64             24       55  29.7
# 1996            8      179             72             42      130  32.7
# 1997            6       85             78              0        0  31.2
# 1998            0      129            110             46      130  67.1
# 1999            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.127   47        1
# ...

# %%
#Check the Data Types of each column in the dataset:-
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
#Check The Null Values:-
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#As we see there is no null values in the datset.we can also see the datatypes of each column is int or float.
#So no Null Values in the Dataset.

# %%
#Now Check For The Duplicate Entries:-
df.duplicated().sum()
# Out:
# 1256

# %%
df[df.duplicated()]
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 483             0       84             82             31      125  38.2
# 484             0      145              0              0        0  44.2
# 485             0      135             68             42      250  42.3
# 486             1      139             62             41      480  40.7
# 487             0      173             78             32      265  46.5
# ...           ...      ...            ...            ...      ...   ...
# 1995            2       75             64             24       55  29.7
# 1996            8      179             72             42      130  32.7
# 1997            6       85             78              0        0  31.2
# 1998            0      129            110             46      130  67.1
# 1999            2       81             72             15       76  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 483                      0.233   23        0
# ...

# %%
#As we Can See That There are Many Duplicate Records in the dataset.So first we have to Delete Thode Records.
df.drop_duplicates(inplace=True)

# %%
#Now Again Check The Duplicates:-
df.duplicated().sum()
# Out:
# 0

# %%
#Now The Duplicated Are Removed So Now Lets Check How Many Records Are Remaing:-
df.shape
# Out:
# (744, 9)

# %%
df
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0               2      138             62             35        0  33.6
# 1               0       84             82             31      125  38.2
# 2               0      145              0              0        0  44.2
# 3               0      135             68             42      250  42.3
# 4               1      139             62             41      480  40.7
# ...           ...      ...            ...            ...      ...   ...
# 1564            1      100             62              0        0  64.4
# 1565            0      163             40             23       64  40.7
# 1566            6      139             84             37        0  50.7
# 1567            2      167             44             30      140  52.7
# 1568            3      162              0            110      215  48.7
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.127   47        1
# ...

# %%
#Now We Can Also See That Many Columns Have value 0 in them,just Take A Look in them:-
#We Can Understand That columns Like Pregnancies And Outcome may Have Value like 0 in them.
#But Rest Of The Columns Having Value 0 does not make Any Sense

# %%
#First Just Take A Look In The Column Glucose:-
A=df['Glucose']
c=0 #initialise counter variable
for index,value in enumerate(A):
    if value==0:
        print(index," ",value)
        c=c+1
print("Number of rows found with special characters: ",c)
# Out:
# 20   0
# 75   0
# 182   0
# 342   0
# 349   0
# Number of rows found with special characters:  5

# %%
#Now We Will Just Take A Look In The Column BloodPressure:-
A=df['BloodPressure']
c=0 #initialise counter variable
for index,value in enumerate(A):
    if value==0:
        print(index," ",value)
        c=c+1
print("Number of rows found with special characters: ",c)
# Out:
# 2   0
# 12   0
# 49   0
# 60   0
# 78   0
# 81   0
# 172   0
# 193   0
# 222   0
# 261   0
# 266   0
# 269   0
# 300   0
# 332   0
# 336   0
# 347   0
# 357   0
# 426   0
# 430   0
# 435   0
# 453   0
# 468   0
# 489   0
# 500   0
# 502   0
# 556   0
# 568   0
# 571   0
# 586   0
# 610   0
# 664   0
# 670   0
# 673   0
# 743   0
# Number of rows found with special characters:  34

# %%
#Now We Will Just Take A Look In The Column SkinThickness:-
A=df['SkinThickness']
c=0 #initialise counter variable
for index,value in enumerate(A):
    if value==0:
        print(index," ",value)
        c=c+1
print("Number of rows found with special characters: ",c)
# Out:
# 2   0
# 7   0
# 12   0
# 13   0
# 14   0
# 23   0
# 27   0
# 30   0
# 31   0
# 36   0
# 41   0
# 44   0
# 46   0
# 49   0
# 58   0
# 60   0
# 61   0
# 62   0
# 64   0
# 67   0
# 72   0
# 76   0
# 78   0
# 81   0
# 84   0
# 90   0
# 93   0
# 100   0
# 101   0
# 102   0
# 104   0
# 106   0
# 113   0
# 115   0
# 116   0
# 117   0
# 123   0
# 124   0
# 129   0
# 131   0
# 138   0
# 140   0
# 143   0
# 148   0
# 151   0
# 154   0
# 164   0
# 167   0
# 168   0
# 170   0
# 176   0
# 178   0
# 179   0
# 180   0
# 183   0
# 184   0
# 190   0
# 192   0
# 193   0
# 196   0
# 201   0
# 207   0
# 219   0
# 221   0
# 222   0
# 226   0
# 230   0
# 233   0
# 235   0
# 239   0
# 242   0
# 246   0
# 250   0
# 251   0
# 261   0
# 264   0
# 266   0
# 268   0
# 269   0
# 272   0
# 274   0
# 278   0
# 280   0
# 283   0
# 284   0
# 294   0
# 299   0
# 300   0
# 303   0
# 304   0
# 317   0
# 319   0
# 327   0
# 332   0
# 333   0
# 336   0
# 337   0
# 339   0
# 343   0
# 344   0
# 347   0
# 350   0
# ...

# %%
#Now We Will Just Take A Look In The Column Insulin:-
A=df['Insulin']
c=0 #initialise counter variable
for index,value in enumerate(A):
    if value==0:
        print(index," ",value)
        c=c+1
print("Number of rows found with special characters: ",c)
# Out:
# 0   0
# 2   0
# 6   0
# 7   0
# 9   0
# 10   0
# 12   0
# 13   0
# 14   0
# 19   0
# 20   0
# 22   0
# 23   0
# 27   0
# 28   0
# 30   0
# 31   0
# 34   0
# 36   0
# 37   0
# 38   0
# 41   0
# 42   0
# 44   0
# 45   0
# 46   0
# 47   0
# 48   0
# 49   0
# 55   0
# 58   0
# 60   0
# 61   0
# 62   0
# 64   0
# 65   0
# 66   0
# 67   0
# 72   0
# 74   0
# 75   0
# 76   0
# 77   0
# 78   0
# 79   0
# 80   0
# 81   0
# 83   0
# 84   0
# 86   0
# 89   0
# 90   0
# 93   0
# 96   0
# 100   0
# 101   0
# 102   0
# 104   0
# 106   0
# 113   0
# 115   0
# 116   0
# 117   0
# 118   0
# 121   0
# 123   0
# 124   0
# 129   0
# 131   0
# 133   0
# 138   0
# 140   0
# 141   0
# 143   0
# 145   0
# 146   0
# 148   0
# 149   0
# 151   0
# 154   0
# 155   0
# 160   0
# 163   0
# 164   0
# 166   0
# 167   0
# 168   0
# 170   0
# 172   0
# 176   0
# 178   0
# 179   0
# 180   0
# 183   0
# 184   0
# 185   0
# 190   0
# 192   0
# 193   0
# 194   0
# 196   0
# 200   0
# 201   0
# 202   0
# 205   0
# ...

# %%
#Now We Will Just Take A Look In The Column BMI:-
A=df['BMI']
c=0 #initialise counter variable
for index,value in enumerate(A):
    if value==0:
        print(index," ",value)
        c=c+1
print("Number of rows found with special characters: ",c)
# Out:
# 12   0.0
# 49   0.0
# 60   0.0
# 81   0.0
# 145   0.0
# 371   0.0
# 426   0.0
# 489   0.0
# 651   0.0
# 673   0.0
# Number of rows found with special characters:  10

# %%
#Now We Will Just Take A Look In The Column DiabetesPedigreeFunction:-
A=df['DiabetesPedigreeFunction']
c=0 #initialise counter variable
for index,value in enumerate(A):
    if value==0:
        print(index," ",value)
        c=c+1
print("Number of rows found with special characters: ",c)
# Out:
# Number of rows found with special characters:  0

# %%
#Now We Will Just Take A Look In The Column Age:-
A=df['Age']
c=0 #initialise counter variable
for index,value in enumerate(A):
    if value==0:
        print(index," ",value)
        c=c+1
print("Number of rows found with special characters: ",c)
# Out:
# Number of rows found with special characters:  0

# %%
#So from abvove information we can say that:-
#Column Glucose Has 5 Zeroes.
#Column BloodPressure Has 34 Zeroes.
#Column SkinThickness Has 215 Zeroes.
#Column Insulin Has 359 Zeroes.
#Column BMI Has 10 Zeroes.
#Column DiabetesPedigreeFunction Has 0 Zeroes.
#Column Age Has 0 Zeroes.

# %%
#So Glucose,BloodPressure,SkinThickness,Insulin,BMI Cannot be 0 for any human being.

# %%
#So what will do is we will replace the Zeros in each with Null Value i.e. np.nan
df['Glucose'].replace(0,np.nan,inplace=True)
df['BloodPressure'].replace(0,np.nan,inplace=True)
df['SkinThickness'].replace(0,np.nan,inplace=True)
df['Insulin'].replace(0,np.nan,inplace=True)
df['BMI'].replace(0,np.nan,inplace=True)

# %%
df.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                34
# SkinThickness               215
# Insulin                     359
# BMI                          10
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                     float64
# BloodPressure               float64
# SkinThickness               float64
# Insulin                     float64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
#Find the percentage of the null values in each column in given dataset:-
df.isnull().sum()/df.shape[0]*100
# Out:
# Pregnancies                  0.000000
# Glucose                      0.672043
# BloodPressure                4.569892
# SkinThickness               28.897849
# Insulin                     48.252688
# BMI                          1.344086
# DiabetesPedigreeFunction     0.000000
# Age                          0.000000
# Outcome                      0.000000
# dtype: float64

# %%
#If the percentage of null values is less than 50% then fill the dataset:-
#Fill null values with mean of that column permanently:fillna()
#So we Will fill the Null values of column Glucose,BloodPressure,SkinThickness,Insulin,BMI

# %%
#Find the mean of Glucose column:-
m=df['Glucose'].mean()
df['Glucose'].fillna(m,inplace=True)
n=df['BloodPressure'].mean()
df['BloodPressure'].fillna(m,inplace=True)
o=df['SkinThickness'].mean()
df['SkinThickness'].fillna(m,inplace=True)
p=df['Insulin'].mean()
df['Insulin'].fillna(m,inplace=True)
q=df['BMI'].mean()
df['BMI'].fillna(m,inplace=True)

# %%
#Now Again Check the Null Values:-
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#Now check the data types of each column:-
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                     float64
# BloodPressure               float64
# SkinThickness               float64
# Insulin                     float64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0               2    138.0      62.000000      35.000000  121.710419  33.6
# 1               0     84.0      82.000000      31.000000  125.000000  38.2
# 2               0    145.0     121.710419     121.710419  121.710419  44.2
# 3               0    135.0      68.000000      42.000000  250.000000  42.3
# 4               1    139.0      62.000000      41.000000  480.000000  40.7
# ...           ...      ...            ...            ...         ...   ...
# 1564            1    100.0      62.000000     121.710419  121.710419  64.4
# 1565            0    163.0      40.000000      23.000000   64.000000  40.7
# 1566            6    139.0      84.000000      37.000000  121.710419  50.7
# 1567            2    167.0      44.000000      30.000000  140.000000  52.7
# 1568            3    162.0     121.710419     110.000000  215.000000  48.7
#
#       DiabetesPedigreeFunction  Age  Outcome
# ...

# %%
df.shape
# Out:
# (744, 9)

# %%
#We Have 744 Records So we will procced with them:-
#As we Know That In The Above DataSet The Column Named Outcome is the Output Column.
#So first just take a look at how many types of output are present in the Outcome Column:-
df['Outcome'].value_counts()
# Out:
# 0    491
# 1    253
# Name: Outcome, dtype: int64

# %%
#As we can see that there are only two types of outputs ion the Outcome Column.
#i.e. 0=>Not Diabetic  And  1=>Diabetic

# %%
#Visualize the output column:-
sns.countplot(data=df,x='Outcome')
f=df['Outcome'].value_counts()
plt.yticks(f)
plt.show()

# %%
#As we can see That the Data is Balanced.

# %%
#Now Select the Input And Output:-
X=df.drop('Outcome',axis=1)
Y=df['Outcome']

# %%
X
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0               2    138.0      62.000000      35.000000  121.710419  33.6
# 1               0     84.0      82.000000      31.000000  125.000000  38.2
# 2               0    145.0     121.710419     121.710419  121.710419  44.2
# 3               0    135.0      68.000000      42.000000  250.000000  42.3
# 4               1    139.0      62.000000      41.000000  480.000000  40.7
# ...           ...      ...            ...            ...         ...   ...
# 1564            1    100.0      62.000000     121.710419  121.710419  64.4
# 1565            0    163.0      40.000000      23.000000   64.000000  40.7
# 1566            6    139.0      84.000000      37.000000  121.710419  50.7
# 1567            2    167.0      44.000000      30.000000  140.000000  52.7
# 1568            3    162.0     121.710419     110.000000  215.000000  48.7
#
#       DiabetesPedigreeFunction  Age
# ...

# %%
Y
# Out:
# 0       1
# 1       0
# 2       1
# 3       1
# 4       0
#        ..
# 1564    0
# 1565    0
# 1566    1
# 1567    0
# 1568    0
# Name: Outcome, Length: 744, dtype: int64

# %%
#Divide The Dataset Into 2 parts i.e. Training(70%) and Testing(30%)
from sklearn.model_selection import train_test_split
#Apply It:-
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.3,random_state=1)

# %%
X_train.shape,Y_train.shape
# Out:
# ((520, 8), (520,))

# %%
X_test.shape,Y_test.shape
# Out:
# ((224, 8), (224,))

# %%
#Now Before Giving The data To the Machine We have to Perform Scaling i.e Standard Scaling on the Dataset:-
from sklearn.preprocessing import StandardScaler
#Create An Object Of The Standard Scaler Class:-
ss=StandardScaler()
#Apply It:-
X_train=ss.fit_transform(X_train)
X_test=ss.transform(X_test)

# %%
X_train
# Out:
# array([[ 1.62628812,  0.76085314,  0.80064527, ..., -0.25789349,
#          0.92304681,  1.76483205],
#        [-0.80118177, -1.69056114,  0.19654415, ...,  0.01209549,
#         -0.15383619, -1.03654211],
#        [ 1.32285439,  0.13143596,  0.80064527, ...,  0.50552364,
#         -0.37908679,  1.41466028],
#        ...,
#        [ 2.84002307,  0.13143596,  0.92146549, ...,  0.96171193,
#          0.34294938,  0.80185968],
#        [ 0.10911944,  1.62216086, -0.16591653, ...,  0.98033186,
#          0.02204441, -0.5988274 ],
#        [ 1.62628812, -0.66361732,  0.07572392, ..., -0.0158344 ,
#          0.5959706 ,  1.15203145]])

# %%
X_test
# Out:
# array([[ 0.10911944,  2.21845082,  2.12966773, ..., -0.42547287,
#          0.64225497,  0.36414497],
#        [ 0.10911944,  1.191507  ,  0.19654415, ..., -0.0158344 ,
#          1.0217868 , -0.16111268],
#        [-0.1943143 , -1.25990728, -0.16591653, ...,  0.3844941 ,
#         -0.63210801, -0.42374151],
#        ...,
#        [ 0.41255318,  0.46270816,  0.43818459, ...,  8.25238462,
#          0.51882998,  3.16551912],
#        [ 0.41255318,  1.5227792 , -0.64919742, ..., -0.0158344 ,
#         -1.03941046,  0.71431674],
#        [ 0.71598691,  0.72772592, -0.16591653, ...,  0.07726525,
#         -0.6691355 ,  0.6267738 ]])

# %%
#Now Create A User Function To Train And Test The Data in with Every Algorithm Possible:-
def create_model(model):
    #train Model
    model.fit(X_train,Y_train)
    #test Model
    Y_predict=model.predict(X_test)
    #generating The Report:-
    from sklearn.metrics import classification_report
    print(classification_report(Y_test,Y_predict))
    #Generate The Confusion Matrix:-
    from sklearn.metrics import confusion_matrix
    print(confusion_matrix(Y_test,Y_predict))
    return model

# %%
#Now We are ready to train and test the dataset in each & every algorithm:-

# %% [markdown]
# # Logistic Regression

# %%
#First we will go With Logistic regression:-
from sklearn.linear_model import LogisticRegression
#Create an Object OF the LogisticRegression Class:-
lr=LogisticRegression(random_state=1)
#Apply it on the User Function Model Which We Created:-
lr=create_model(lr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.82      0.83       154
#            1       0.62      0.63      0.62        70
#
#     accuracy                           0.76       224
#    macro avg       0.72      0.73      0.73       224
# weighted avg       0.76      0.76      0.76       224
#
# [[127  27]
#  [ 26  44]]

# %%
#As we can clearly see that the accuracy is not Good.

# %% [markdown]
# # Decision Tree

# %%
#As We have not got good results from Logistic Regression We will go for Decision Tree:-
#Import The DecisionTree Class:-
from sklearn.tree import DecisionTreeClassifier
#Create An Object of the DecisionTreeClassifier
dtc=DecisionTreeClassifier(random_state=1)
#Now implicate it using our User Defined Function Which we created:-
dtc=create_model(dtc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.77      0.80       154
#            1       0.56      0.64      0.60        70
#
#     accuracy                           0.73       224
#    macro avg       0.69      0.71      0.70       224
# weighted avg       0.74      0.73      0.74       224
#
# [[119  35]
#  [ 25  45]]

# %%
#Now We will take a Look At which features are important How important are they:-
dtc.feature_importances_
# Out:
# array([0.07133334, 0.29319401, 0.07628443, 0.0851517 , 0.06123578,
#        0.13587506, 0.15781187, 0.11911383])

# %%
X.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age'],
#       dtype='object')

# %%
#Lets Make a Dictionary of the columns and their Information Gain and arrange it in a descending order:-
dict={'Input':X.columns,'IG':dtc.feature_importances_}
df1=pd.DataFrame(dict)
df1.sort_values('IG',axis=0,ascending=False,ignore_index=True)
# Out:
#                       Input        IG
# 0                   Glucose  0.293194
# 1  DiabetesPedigreeFunction  0.157812
# 2                       BMI  0.135875
# 3                       Age  0.119114
# 4             SkinThickness  0.085152
# 5             BloodPressure  0.076284
# 6               Pregnancies  0.071333
# 7                   Insulin  0.061236

# %%
#Lets Visualize The DecisionTree:-
from sklearn import tree
plt.figure(figsize=(16,19))
features=X.columns
_=tree.plot_tree(dtc,feature_names=features,filled=True)

# %%
#Here In Normal DecisionTree 0 is 77 and 1 is 64

# %% [markdown]
# # PruningTechnique:- Max_depth

# %%
#Now Lets Apply The Pruning Technique:-
#First We will use Max_depth:-
for i in range(1,9):
    #Preparing The Model by Calling The Class
    dtc1=DecisionTreeClassifier(max_depth=i,random_state=1)
    print("Number Of Max_Depth=",i)
    dtc1=create_model(dtc1)
    print()
# Out:
# Number Of Max_Depth= 1
#               precision    recall  f1-score   support
#
#            0       0.79      0.88      0.83       154
#            1       0.65      0.47      0.55        70
#
#     accuracy                           0.75       224
#    macro avg       0.72      0.68      0.69       224
# weighted avg       0.74      0.75      0.74       224
#
# [[136  18]
#  [ 37  33]]
#
# Number Of Max_Depth= 2
#               precision    recall  f1-score   support
#
#            0       0.79      0.88      0.83       154
#            1       0.65      0.47      0.55        70
#
#     accuracy                           0.75       224
#    macro avg       0.72      0.68      0.69       224
# weighted avg       0.74      0.75      0.74       224
#
# [[136  18]
#  [ 37  33]]
#
# Number Of Max_Depth= 3
#               precision    recall  f1-score   support
#
#            0       0.77      0.89      0.82       154
#            1       0.62      0.40      0.49        70
#
# ...

# %%
#So will set the value of max_depth as 8:-
dtc1=DecisionTreeClassifier(max_depth=8,random_state=1)
#Call the Function:-
dtc1=create_model(dtc1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.71      0.77       154
#            1       0.53      0.73      0.61        70
#
#     accuracy                           0.71       224
#    macro avg       0.69      0.72      0.69       224
# weighted avg       0.75      0.71      0.72       224
#
# [[109  45]
#  [ 19  51]]

# %%
#Lets Visualize The DecisionTree:-
from sklearn import tree
plt.figure(figsize=(10,10))
features=X.columns
_=tree.plot_tree(dtc1,feature_names=features,filled=True)

# %%
#Lets Make a Dictionary of the columns and their Information Gain and arrange it in a descending order:-
dict={'Input':X.columns,'IG':dtc1.feature_importances_}
df2=pd.DataFrame(dict)
df2.sort_values('IG',axis=0,ascending=False,ignore_index=True)
# Out:
#                       Input        IG
# 0                   Glucose  0.380313
# 1                       BMI  0.150294
# 2  DiabetesPedigreeFunction  0.143029
# 3                       Age  0.110564
# 4               Pregnancies  0.068341
# 5             SkinThickness  0.060185
# 6                   Insulin  0.047625
# 7             BloodPressure  0.039648

# %%
#As we can See That When The Max_depth is 8 then it is showing good result as compared with the previous One.
#Here In max_depth=8 0 is 0.71 and 1 is 0.73

# %% [markdown]
# # Pruning Technique:-min_samples_leaf

# %%
#Now we will go for the second prining Technique:-min_samples_leaf:-
for i in range(45,101):
    dtc2=DecisionTreeClassifier(min_samples_leaf=i,random_state=1)
    print("The Number Of min_sample_leaf=",i)
    dtc2=create_model(dtc2)
    print()
# Out:
# The Number Of min_sample_leaf= 45
#               precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82       154
#            1       0.59      0.63      0.61        70
#
#     accuracy                           0.75       224
#    macro avg       0.71      0.72      0.71       224
# weighted avg       0.75      0.75      0.75       224
#
# [[124  30]
#  [ 26  44]]
#
# The Number Of min_sample_leaf= 46
#               precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82       154
#            1       0.59      0.63      0.61        70
#
#     accuracy                           0.75       224
#    macro avg       0.71      0.72      0.71       224
# weighted avg       0.75      0.75      0.75       224
#
# [[124  30]
#  [ 26  44]]
#
# The Number Of min_sample_leaf= 47
#               precision    recall  f1-score   support
#
#            0       0.85      0.77      0.81       154
# ...

# %%
#We will Set The value of min_samples_leaf as 75:-
dtc2=DecisionTreeClassifier(min_samples_leaf=75,random_state=1)
#Call The Function:-
dtc2=create_model(dtc2)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.73      0.80       154
#            1       0.58      0.81      0.67        70
#
#     accuracy                           0.75       224
#    macro avg       0.74      0.77      0.74       224
# weighted avg       0.80      0.75      0.76       224
#
# [[112  42]
#  [ 13  57]]

# %%
#Lets Visualize The DecisionTree:-
from sklearn import tree
plt.figure(figsize=(10,10))
features=X.columns
_=tree.plot_tree(dtc2,feature_names=features,filled=True)

# %%
#Lets Make a Dictionary of the columns and their Information Gain and arrange it in a descending order:-
dict={'Input':X.columns,'IG':dtc2.feature_importances_}
df3=pd.DataFrame(dict)
df3.sort_values('IG',axis=0,ascending=False,ignore_index=True)
# Out:
#                       Input        IG
# 0                   Glucose  0.656165
# 1                       BMI  0.196055
# 2                       Age  0.147780
# 3               Pregnancies  0.000000
# 4             BloodPressure  0.000000
# 5             SkinThickness  0.000000
# 6                   Insulin  0.000000
# 7  DiabetesPedigreeFunction  0.000000

# %%
#So we can see that the abive Model Is showing Good Result as compared to the previous One:-
#In min_samples_leaf=75 0 is 73 and 1 is 0.81

# %% [markdown]
# # DecisionTree With Entropy

# %%
#Now Lets Use The DecisionTreeClassifier Pruning Technique Using Entropy:-
dte=DecisionTreeClassifier(random_state=1,criterion='entropy')
#Lets Call The Function:-
dte=create_model(dte)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.78      0.78       154
#            1       0.51      0.50      0.50        70
#
#     accuracy                           0.69       224
#    macro avg       0.64      0.64      0.64       224
# weighted avg       0.69      0.69      0.69       224
#
# [[120  34]
#  [ 35  35]]

# %%
#In Normal DecisionTreeClassifier With Entropy 0 is 0.78 and 1 is 0.50

# %% [markdown]
# # max-depth with entropy

# %%
#We Can Also Use The Pruning Technique with Entropy and see what we find:-
#First max-depth with entropy:-
for i in range(1,9):
    #Preparing The Model by Calling The Class
    dte1=DecisionTreeClassifier(max_depth=i,criterion='entropy',random_state=1)
    print("Number Of Max_Depth=",i)
    dte1=create_model(dte1)
    print()
# Out:
# Number Of Max_Depth= 1
#               precision    recall  f1-score   support
#
#            0       0.79      0.88      0.83       154
#            1       0.65      0.47      0.55        70
#
#     accuracy                           0.75       224
#    macro avg       0.72      0.68      0.69       224
# weighted avg       0.74      0.75      0.74       224
#
# [[136  18]
#  [ 37  33]]
#
# Number Of Max_Depth= 2
#               precision    recall  f1-score   support
#
#            0       0.79      0.88      0.83       154
#            1       0.65      0.47      0.55        70
#
#     accuracy                           0.75       224
#    macro avg       0.72      0.68      0.69       224
# weighted avg       0.74      0.75      0.74       224
#
# [[136  18]
#  [ 37  33]]
#
# Number Of Max_Depth= 3
#               precision    recall  f1-score   support
#
#            0       0.77      0.89      0.82       154
#            1       0.62      0.40      0.49        70
#
# ...

# %%
#We can set the value of max_depth as 4:-
dte1=DecisionTreeClassifier(max_depth=4,criterion='entropy',random_state=1)
#Call The Function:-
dte1=create_model(dte1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.68      0.77       154
#            1       0.54      0.81      0.65        70
#
#     accuracy                           0.72       224
#    macro avg       0.71      0.75      0.71       224
# weighted avg       0.78      0.72      0.73       224
#
# [[105  49]
#  [ 13  57]]

# %%
#Lets Make a Dictionary of the columns and their Information Gain and arrange it in a descending order:-
dict={'Input':X.columns,'IG':dte1.feature_importances_}
df4=pd.DataFrame(dict)
df4.sort_values('IG',axis=0,ascending=False,ignore_index=True)
# Out:
#                       Input        IG
# 0                   Glucose  0.522130
# 1                       BMI  0.257118
# 2                       Age  0.100291
# 3                   Insulin  0.066028
# 4  DiabetesPedigreeFunction  0.029886
# 5             SkinThickness  0.024548
# 6               Pregnancies  0.000000
# 7             BloodPressure  0.000000

# %%
#Lets Visualize The DecisionTree:-
from sklearn import tree
plt.figure(figsize=(10,10))
features=X.columns
_=tree.plot_tree(dte1,feature_names=features,filled=True)

# %%
#In max_depth with entropy 0 is 0.68 and 1 is 0.81

# %% [markdown]
# # min_samples_leaf with Entropy

# %%
#Now Lets Try min_samples_leaf with Entropy:-
for i in range(45,101):
    dte2=DecisionTreeClassifier(min_samples_leaf=i,criterion='entropy',random_state=1)
    print("Number of min_samples_leaf=",i)
    dte2=create_model(dte2)
    print()
# Out:
# Number of min_samples_leaf= 45
#               precision    recall  f1-score   support
#
#            0       0.82      0.81      0.82       154
#            1       0.60      0.61      0.61        70
#
#     accuracy                           0.75       224
#    macro avg       0.71      0.71      0.71       224
# weighted avg       0.75      0.75      0.75       224
#
# [[125  29]
#  [ 27  43]]
#
# Number of min_samples_leaf= 46
#               precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82       154
#            1       0.60      0.63      0.62        70
#
#     accuracy                           0.75       224
#    macro avg       0.72      0.72      0.72       224
# weighted avg       0.76      0.75      0.76       224
#
# [[125  29]
#  [ 26  44]]
#
# Number of min_samples_leaf= 47
#               precision    recall  f1-score   support
#
#            0       0.85      0.79      0.82       154
# ...

# %%
#We Can Set The Value Of min_samples_leaf=68
dte2=DecisionTreeClassifier(min_samples_leaf=68,criterion='entropy',random_state=1)
#Call The Function:-
dte2=create_model(dte2)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.73      0.80       154
#            1       0.58      0.81      0.67        70
#
#     accuracy                           0.75       224
#    macro avg       0.74      0.77      0.74       224
# weighted avg       0.80      0.75      0.76       224
#
# [[112  42]
#  [ 13  57]]

# %%
#Lets Make a Dictionary of the columns and their Information Gain and arrange it in a descending order:-
dict={'Input':X.columns,'IG':dte2.feature_importances_}
df5=pd.DataFrame(dict)
df5.sort_values('IG',axis=0,ascending=False,ignore_index=True)
# Out:
#                       Input        IG
# 0                   Glucose  0.615058
# 1                       BMI  0.265827
# 2                       Age  0.119115
# 3               Pregnancies  0.000000
# 4             BloodPressure  0.000000
# 5             SkinThickness  0.000000
# 6                   Insulin  0.000000
# 7  DiabetesPedigreeFunction  0.000000

# %%
#Lets Visualize The DecisionTree:-
from sklearn import tree
plt.figure(figsize=(10,10))
features=X.columns
_=tree.plot_tree(dte2,feature_names=features,filled=True)

# %%
#With min_samples_leaf with entropy 0 is 73 and 1 is 0.81.

# %% [markdown]
# # Ensembling Technique
# Now will Move towards the ensembling Techniques.
# First one is the RandomForest Classifier.

# %% [markdown]
# # RandomForest Classifier

# %%
#We Have to import the RandomForest Classifier first
from sklearn.ensemble import RandomForestClassifier

# %%
#This Is also Hit and run type of technique:-
for i in range(8,0,-1):
    #Create An object of The RandomForest Classifier
    rfc=RandomForestClassifier(n_estimators=10,max_features=i,random_state=1) #By default gini index
    print("Number Of Features:",i)
    #Call The Function
    rfc=create_model(rfc)
    print()
# Out:
# Number Of Features: 8
#               precision    recall  f1-score   support
#
#            0       0.79      0.88      0.83       154
#            1       0.65      0.47      0.55        70
#
#     accuracy                           0.75       224
#    macro avg       0.72      0.68      0.69       224
# weighted avg       0.74      0.75      0.74       224
#
# [[136  18]
#  [ 37  33]]
#
# Number Of Features: 7
#               precision    recall  f1-score   support
#
#            0       0.80      0.84      0.82       154
#            1       0.61      0.53      0.56        70
#
#     accuracy                           0.75       224
#    macro avg       0.70      0.69      0.69       224
# weighted avg       0.74      0.75      0.74       224
#
# [[130  24]
#  [ 33  37]]
#
# Number Of Features: 6
#               precision    recall  f1-score   support
#
#            0       0.80      0.88      0.84       154
#            1       0.67      0.53      0.59        70
#
# ...

# %%
#We can set the Number Of Featires 5 i.e. max_features=5
rfc=RandomForestClassifier(n_estimators=10,max_features=5,random_state=1)
#Call The Function:-
rfc=create_model(rfc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.83      0.83       154
#            1       0.62      0.60      0.61        70
#
#     accuracy                           0.76       224
#    macro avg       0.72      0.72      0.72       224
# weighted avg       0.76      0.76      0.76       224
#
# [[128  26]
#  [ 28  42]]

# %%
#As a result the best from above gives 0 is 0.83 and 1 is 60.

# %% [markdown]
# # RandomForest Classifier with Entropy

# %%
#This Is also Hit and run type of technique:-
for i in range(8,0,-1):
    #Create An object of The RandomForest Classifier
    rfc=RandomForestClassifier(n_estimators=10,max_features=i,random_state=1,criterion='entropy') 
    print("Number Of Features:",i)
    #Call The Function
    rfc=create_model(rfc)
    print()
# Out:
# Number Of Features: 8
#               precision    recall  f1-score   support
#
#            0       0.80      0.85      0.83       154
#            1       0.62      0.54      0.58        70
#
#     accuracy                           0.75       224
#    macro avg       0.71      0.70      0.70       224
# weighted avg       0.75      0.75      0.75       224
#
# [[131  23]
#  [ 32  38]]
#
# Number Of Features: 7
#               precision    recall  f1-score   support
#
#            0       0.82      0.85      0.84       154
#            1       0.65      0.60      0.62        70
#
#     accuracy                           0.77       224
#    macro avg       0.74      0.73      0.73       224
# weighted avg       0.77      0.77      0.77       224
#
# [[131  23]
#  [ 28  42]]
#
# Number Of Features: 6
#               precision    recall  f1-score   support
#
#            0       0.81      0.86      0.84       154
#            1       0.65      0.57      0.61        70
#
# ...

# %%
#We can set the Number Of Featires 4 i.e. max_features=4
rfc=RandomForestClassifier(n_estimators=10,max_features=4,random_state=1,criterion='entropy')
#Call The Function:-
rfc=create_model(rfc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85       154
#            1       0.67      0.63      0.65        70
#
#     accuracy                           0.79       224
#    macro avg       0.75      0.74      0.75       224
# weighted avg       0.78      0.79      0.78       224
#
# [[132  22]
#  [ 26  44]]

# %%
#As a result we can see that using entropy gives us better accuracy as compared to the RandomForest Classifier by gini Index.
#And the Max_features is also Less Than The RandomForestClassifier by gini index.
#As a result it gives us 0 is 86 and 1 is 63.

# %% [markdown]
# # ADA-Boost
# It is one of the Boosting techniques.
# Lets see how This runs:-

# %%
#Import the class first:-
from sklearn.ensemble import AdaBoostClassifier

# %%
#Create The Object Of the AdaBoostClassifier Class:-
abc=AdaBoostClassifier()

# %%
#Using The Hit And Trial Method TO find the Exact n_estimators:-
for i in range(10,101):
    #preparing the model
    abc=AdaBoostClassifier(n_estimators=i,random_state=1)
    print('no of decision stump',i)
    #Call The Function:-
    abc=create_model(abc)
    print()
# Out:
# no of decision stump 10
#               precision    recall  f1-score   support
#
#            0       0.81      0.84      0.82       154
#            1       0.61      0.56      0.58        70
#
#     accuracy                           0.75       224
#    macro avg       0.71      0.70      0.70       224
# weighted avg       0.74      0.75      0.75       224
#
# [[129  25]
#  [ 31  39]]
#
# no of decision stump 11
#               precision    recall  f1-score   support
#
#            0       0.81      0.84      0.82       154
#            1       0.61      0.56      0.58        70
#
#     accuracy                           0.75       224
#    macro avg       0.71      0.70      0.70       224
# weighted avg       0.74      0.75      0.75       224
#
# [[129  25]
#  [ 31  39]]
#
# no of decision stump 12
#               precision    recall  f1-score   support
#
#            0       0.81      0.84      0.83       154
#            1       0.62      0.56      0.59        70
#
# ...

# %%
#In decision Stump 15 we got good recall accuracy as compared with others:-
abc=AdaBoostClassifier(n_estimators=15,random_state=1)
#Call the function:-
abc=create_model(abc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.81      0.84       154
#            1       0.63      0.73      0.68        70
#
#     accuracy                           0.78       224
#    macro avg       0.75      0.77      0.76       224
# weighted avg       0.79      0.78      0.79       224
#
# [[124  30]
#  [ 19  51]]

# %%
#AdaBoost Classifier Gives Us 0 is 0.81 and 1 is 0.73

# %% [markdown]
# # Gradient Boosting
# Second Type of Boosting Lets see how this works:-

# %%
#call the GradientBoostingClassifier class in sklearn.ensemble library
from sklearn.ensemble import GradientBoostingClassifier

# %%
#create the object of GradientBoostingClassifierb
gb=GradientBoostingClassifier()

# %%
#Using The Hit And Trial Method TO find the Exact n_estimators:-
for i in range(10,101):
    #preparing the model
    gb=GradientBoostingClassifier(n_estimators=i,random_state=1)
    print('no of decision stump',i)
    #Call The Function:-
    gb=create_model(gb)
    print()
# Out:
# no of decision stump 10
#               precision    recall  f1-score   support
#
#            0       0.79      0.92      0.85       154
#            1       0.71      0.46      0.56        70
#
#     accuracy                           0.77       224
#    macro avg       0.75      0.69      0.70       224
# weighted avg       0.76      0.77      0.76       224
#
# [[141  13]
#  [ 38  32]]
#
# no of decision stump 11
#               precision    recall  f1-score   support
#
#            0       0.81      0.91      0.86       154
#            1       0.73      0.53      0.61        70
#
#     accuracy                           0.79       224
#    macro avg       0.77      0.72      0.73       224
# weighted avg       0.78      0.79      0.78       224
#
# [[140  14]
#  [ 33  37]]
#
# no of decision stump 12
#               precision    recall  f1-score   support
#
#            0       0.80      0.91      0.85       154
#            1       0.72      0.51      0.60        70
#
# ...

# %%
#In decision Stump 20 we got good recall accuracy as compared with others:-
gb=GradientBoostingClassifier(n_estimators=20,random_state=1)
#Call the function:-
gb=create_model(gb)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86       154
#            1       0.70      0.63      0.66        70
#
#     accuracy                           0.80       224
#    macro avg       0.77      0.75      0.76       224
# weighted avg       0.79      0.80      0.80       224
#
# [[135  19]
#  [ 26  44]]

# %%
#Gradient Boosting Is giving 0 as 0.88 and 1 as 0.63

# %% [markdown]
# # Extereme Gradient Boosting

# %%
# !pip install xgboost

# %%
#Import GGBClassifier from the xgboost Library
from xgboost import XGBClassifier

# %%
#Create an object of the XGBClassifier Class:-
xgb=XGBClassifier()

# %%
for i in range(10,101,1):
    #prparing the model
    #creating the object of XGBClassifier class
    #automatic overfitting: reg means regularization and alpha or lambda:
    #hyperparameter
    xgc=XGBClassifier(n_estimators=i,reg_alpha=1,random_state=1)
    print('no of estimator',i)
    #calling functon
    xgc=create_model(xgc)
    print()
# Out:
# no of estimator 10
#               precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83       154
#            1       0.62      0.69      0.65        70
#
#     accuracy                           0.77       224
#    macro avg       0.74      0.75      0.74       224
# weighted avg       0.78      0.77      0.78       224
#
# [[125  29]
#  [ 22  48]]
#
# no of estimator 11
#               precision    recall  f1-score   support
#
#            0       0.86      0.81      0.83       154
#            1       0.63      0.70      0.66        70
#
#     accuracy                           0.78       224
#    macro avg       0.74      0.76      0.75       224
# weighted avg       0.78      0.78      0.78       224
#
# [[125  29]
#  [ 21  49]]
#
# no of estimator 12
#               precision    recall  f1-score   support
#
#            0       0.84      0.81      0.83       154
#            1       0.62      0.67      0.64        70
#
# ...

# %%
#Numbeer of Estimators=11 gives us good Accuracy as compared to Others:-
xgc=XGBClassifier(n_estimators=11,reg_alpha=1,random_state=1)
#Call The Function:-
xgc=create_model(xgc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.81      0.83       154
#            1       0.63      0.70      0.66        70
#
#     accuracy                           0.78       224
#    macro avg       0.74      0.76      0.75       224
# weighted avg       0.78      0.78      0.78       224
#
# [[125  29]
#  [ 21  49]]

# %%
#Extereme Gradient Boosting Gives us 0 as 0.81 and 1 as 0.70

# %% [markdown]
# # SVM:Support Vector Machine
# There are different types Of SVM:-
# 1. Linear Separable data means Linear Kernal function
# 2. Non -Linear data

# %% [markdown]
# # Linear Separable data means Linear Kernal function

# %%
from sklearn.svm import LinearSVC #LinearSVC means Linear Support Vector Classifier.

# %%
#Create an object of LinearSVC:-
svc=LinearSVC(random_state=1) #bydefault hard margin,suppose no outlier in my dataset means suppose no overfit.
#svc is user defined object

# %%
#Call the function:-
svc=create_model(svc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.85      0.84       154
#            1       0.65      0.60      0.62        70
#
#     accuracy                           0.77       224
#    macro avg       0.74      0.73      0.73       224
# weighted avg       0.77      0.77      0.77       224
#
# [[131  23]
#  [ 28  42]]

# %%
#here recall is 0.60 of 1 category which is not good but we can do more better
#means can be possible ,model is overfit  why 
#perhaps , can be no error on training time but error on testing time , 
#what  do we do ,
#add some external error during training time  if create a object of 
#LinearSVC class 

#Soft margin means to reduced overfitting situation means some error add on
#training time 
#create object of LinearSVC class
#Soft Margin

# %%
#Create object of LinearSVC class and add some Externl Error:-
svc1=LinearSVC(random_state=1,C=0.9) #Soft Margin
#here C is parameter which is used to add some error during training time 
#set range of error 0.001 to 1 means C<=1

# %%
#Call the Function:-
svc1=create_model(svc1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.85      0.84       154
#            1       0.65      0.60      0.62        70
#
#     accuracy                           0.77       224
#    macro avg       0.74      0.73      0.73       224
# weighted avg       0.77      0.77      0.77       224
#
# [[131  23]
#  [ 28  42]]

# %%
#This Shows That Our Data is Not Linear Separatable Data.
#Because No Matter How Much amount of error we increase there is no change in the model.

# %%
#no any effect on recall if error increase or decrease means we conclude ,
#data set is not a linearly separateable means non-linearly data 
#Then use polynomial Kernel function : It is used for Non-Linearly data
#In polynomial Kernal function, increase the dimension means to increase low
#dimension to high dimension

# %%
#Whenever Such Situation Occurs where the data is not linear Separatable then we will give the data to the the kernel function.
#Kernel Function:-There are two types in Kernel Function
#1.Polynomial Kernel Function:-In this situation we will increse the dimensions of the data,
#In This boundary which separates the two classes is called as hyperplane or decision boundary.
#   i.e. if the data is 1 dimensional then we will make it 2 dimensional
#   i.e. if the data is 2 dimensional then we will make it 3 dimensional
#   i.e. if the data is 3 dimensional then we will make it 4 dimensional
#2.Radial Basis Kernel Function:-In this situation if the data is forming a circular pattern.
#In This boundary which separates the two classes is called as hypercircle or decision boundary Circle.

# %%
#Use polynomial kernel function , use inbuilt class SVC(Support Vector Classifier)
from sklearn.svm import SVC
#SVC used for polynomial and radial basis kerne function: both are used for non-linear data.

# %%
#Now create an object of the SVC class and passing the poly in kernel parameter:-
svc1=SVC(random_state=1,kernel='poly')

# %%
#Call Function:-
svc1=create_model(svc1)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.94      0.85       154
#            1       0.75      0.43      0.55        70
#
#     accuracy                           0.78       224
#    macro avg       0.77      0.68      0.70       224
# weighted avg       0.77      0.78      0.76       224
#
# [[144  10]
#  [ 40  30]]

# %%
#Score=43% its not good
#So give the dataset in radial basis kernel function:-
#Create object of SVC class:-
svc2=SVC(random_state=1,kernel='rbf') #rbf means radius basis function

# %%
#Call Function:-
svc2=create_model(svc2)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.86      0.84       154
#            1       0.66      0.60      0.63        70
#
#     accuracy                           0.78       224
#    macro avg       0.74      0.73      0.73       224
# weighted avg       0.77      0.78      0.77       224
#
# [[132  22]
#  [ 28  42]]

# %%
#Conclusion:- Dataset is a non-linear dataset.
#radial basis kernel function.

# %% [markdown]
# # KNN Algorithm

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
#Create The Object OF KNN Class:-
knc=KNeighborsClassifier(n_neighbors=9,metric='minkowski',p=2)
#p=2 means Euclidean distance means sqrt(x2-x1)*2+(y2-y1)*2
#n_neighbors means k means select minimum point (always odd)
#best value of k=9

# %%
#Call The User FUnction:-
knc=create_model(knc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.84      0.85       154
#            1       0.67      0.70      0.69        70
#
#     accuracy                           0.80       224
#    macro avg       0.77      0.77      0.77       224
# weighted avg       0.80      0.80      0.80       224
#
# [[130  24]
#  [ 21  49]]

# %%
#best value for n_neighbors is 9
#Gives us accuracy as 0 is 0.84 and 1 is 0.70

# %% [markdown]
# # Observations

# %%
#1.Logistic Regression:- 0 : 82%      &       1 : 63%

#2.DecisionTree:-  0 : 77%    &    1 : 64%

#    Pruning Technique Max_depth(max_depth=8):- 0 : 71%   &   1 : 73%

#    Pruning Technique min_samples_leaf(min_samples_leaf=75):- 0 : 73%    &   1 : 81%

#3.DecisionTree With Entropy:-  0 : 78%    &    1 : 50%

#    Pruning Technique Max_depth with Entropy(max_depth=4):- 0 : 68%   &   1 : 81%

#    Pruning Technique min_samples_leaf with Entropy(min_samples_leaf=63):- 0 : 73%    &   1 : 81%

#4.RandomForest Classifier:-  0 : 83%    &    1 : 60%

#    RandomForest Classifier With Entropy:-  0 : 86%    &    1 : 63%

#5.Boosting:-

#    ADA Boosting(n_estimators=15):- 0 : 81%    &   1 : 73%

#    Gradient Boosting(n_estimators=20):- 0 : 88%   &    1 :  63%

#    Extreme Gradient Boosting(n_estimators=11):- 0 : 81%   &    1 : 70%

#6.SVM:-

#   Dataset is a non-linear dataset.Radial basis kernel function:- 0  : 86%    &   1 : 60%

#7.KNN:-Best value for n_neighbors is 9.
#       Gives us accuracy as 0 : 84%   &   1 : 70%

# %% [markdown]
# # Conclusion:-
#
# The Pruning Technique Min_Samples_leaf with Entropy is giving the Best Accuracy Of Recall as compared to others:-
#
# 0   :   73%
#
# 1   :   81%

# %%
#We Can Set The Value Of min_samples_leaf=68
dte2=DecisionTreeClassifier(min_samples_leaf=68,criterion='entropy',random_state=1)
#Call The Function:-
dte2=create_model(dte2)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.73      0.80       154
#            1       0.58      0.81      0.67        70
#
#     accuracy                           0.75       224
#    macro avg       0.74      0.77      0.74       224
# weighted avg       0.80      0.75      0.76       224
#
# [[112  42]
#  [ 13  57]]

# %%
#As here are only 13 wrong predictions which are made and which are very less as compared to the others.
